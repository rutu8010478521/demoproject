# %% [markdown]
# <a href="https://colab.research.google.com/github/rutu8010478521/demoproject/blob/main/Python_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
candidates = ["Narendra Modi", "Rahul Gandhi", "Arvind Kejriwal","Nota"]
votes = [0, 0, 0, 0]
voters = []

def display_candidates():
    print("\nCandidates:")
    for i in range(len(candidates)):
        print(f"{i+1}. {candidates[i]}")

def vote():
    voter_id = input("Enter your voter ID: ")

    if voter_id in voters:
        print("You have already voted! Duplicate voting not allowed.")
        return

    display_candidates()

    try:
        choice = int(input("Select candidate number to vote: "))

        if 1 <= choice <= len(candidates):
            votes[choice-1] += 1
            voters.append(voter_id)
            print("Vote recorded successfully!")
        else:
            print("Invalid candidate number.")

    except:
        print("Invalid input!")

def show_results():
    print("\nCurrent Poll Results:")
    total_votes = sum(votes)

    for i in range(len(candidates)):
        if total_votes == 0:
            percent = 0
        else:
            percent = (votes[i] / total_votes) * 100

        print(f"{candidates[i]}: {votes[i]} votes ({percent:.2f}%)")

def winner():
    max_votes = max(votes)
    index = votes.index(max_votes)
    print(f"\nCurrent Leader: {candidates[index]} with {max_votes} votes")

def menu():
    while True:
        print("\n--- Online Polling System ---")
        print("1. Cast Vote")
        print("2. Show Poll Statistics")
        print("3. Show Winner")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            vote()
        elif choice == "2":
            show_results()
        elif choice == "3":
            winner()
        elif choice == "4":
            print("Exiting Poll System")
            break
        else:
            print("Invalid choice!")

menu()















3
# Out:
# --- Online Polling System ---
# 1. Cast Vote
# 2. Show Poll Statistics
# 3. Show Winner
# 4. Exit
# Enter your choice: 1
# Enter your voter ID: 123456
#
# Candidates:
# 1. Narendra Modi
# 2. Rahul Gandhi
# 3. Arvind Kejriwal
# 4. Nota
# Select candidate number to vote: 1
# Vote recorded successfully!
#
# --- Online Polling System ---
# 1. Cast Vote
# 2. Show Poll Statistics
# 3. Show Winner
# 4. Exit
# Enter your choice: 1
# Enter your voter ID: 565656
#
# Candidates:
# 1. Narendra Modi
# 2. Rahul Gandhi
# 3. Arvind Kejriwal
# 4. Nota
# Select candidate number to vote: 2
# Vote recorded successfully!
#
# --- Online Polling System ---
# 1. Cast Vote
# 2. Show Poll Statistics
# 3. Show Winner
# 4. Exit
# Enter your choice: 1
# Enter your voter ID: 654321
#
# Candidates:
# 1. Narendra Modi
# 2. Rahul Gandhi
# 3. Arvind Kejriwal
# 4. Nota
# Select candidate number to vote: 4
# Vote recorded successfully!
#
# --- Online Polling System ---
# 1. Cast Vote
# 2. Show Poll Statistics
# 3. Show Winner
# 4. Exit
# Enter your choice: 1
# Enter your voter ID: 125689
#
# Candidates:
# 1. Narendra Modi
# 2. Rahul Gandhi
# 3. Arvind Kejriwal
# 4. Nota
# Select candidate number to vote: 1
# Vote recorded successfully!
#
# --- Online Polling System ---
# 1. Cast Vote
# 2. Show Poll Statistics
# 3. Show Winner
# 4. Exit
# Enter your choice: 1
# Enter your voter ID: 93095043
#
# Candidates:
# 1. Narendra Modi
# 2. Rahul Gandhi
# 3. Arvind Kejriwal
# 4. Nota
# Select candidate number to vote: 1
# Vote recorded successfully!
#
# --- Online Polling System ---
# 1. Cast Vote
# 2. Show Poll Statistics
# 3. Show Winner
# 4. Exit
# Enter your choice: 1
# Enter your voter ID: 9057462
#
# Candidates:
# 1. Narendra Modi
# 2. Rahul Gandhi
# 3. Arvind Kejriwal
# 4. Nota
# Select candidate number to vote: 3
# Vote recorded successfully!
#
# --- Online Polling System ---
# 1. Cast Vote
# 2. Show Poll Statistics
# 3. Show Winner
# 4. Exit
# Enter your choice: 2
#
# Current Poll Results:
# Narendra Modi: 3 votes (50.00%)
# Rahul Gandhi: 1 votes (16.67%)
# Arvind Kejriwal: 1 votes (16.67%)
# Nota: 1 votes (16.67%)
#
# --- Online Polling System ---
# 1. Cast Vote
# 2. Show Poll Statistics
# 3. Show Winner
# 4. Exit
# Enter your choice: 3
#
# Current Leader: Narendra Modi with 3 votes
#
# --- Online Polling System ---
# 1. Cast Vote
# 2. Show Poll Statistics
# 3. Show Winner
# 4. Exit
# Enter your choice: 4
# Exiting Poll System
